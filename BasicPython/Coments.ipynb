# %%
# Isso é um comentário
print('Linha 1')
# Out:
# Linha 1

# %%
'''
Isso é um comentário
para várias linhas :)
ou multi linhas
'''
print('Linha 2')
# Out:
# Linha 2

# %%
print('Linha 3')  # comentário da linha 3
# Out:
# Linha 3

# %%
# fim de codigo
