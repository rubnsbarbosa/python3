# %%
print(123456)
# Out:
# 123456

# %%
print(2+5)
# Out:
# 7

# %%
print('Rubens', 'Barbosa')
# Out:
# ('Rubens', 'Barbosa')

# %%
print('Rubens Barbosa')
# Out:
# Rubens Barbosa

# %%
print('Rubens' + 'Barbosa')
# Out:
# RubensBarbosa

# %%
print(8*8)
# Out:
# 64

# %%
print('rubens', 'barbosa', sep='-')

# %%
print('123', '543', '987', sep='.', end='-')
print('18')
