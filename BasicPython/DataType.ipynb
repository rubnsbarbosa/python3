# %%
'''
Tipos de dados
str - string / texto 'Exemplo' / "Exemplo2"
int - inteiro (número negativo, positivo ou zero) -45, 36, 0, 13244654
float - ponto flutuante é um (número negativo, positivo ou zero que tenha .) -45.5, 0.0, 984.5
bool - booleano/valor lógico com dois valores - True/False 10 == 10
'''
a = 'letra a'
print(type(a))
# Out:
# <type 'str'>

# %%
b = 10
print(type(b))
# Out:
# <type 'int'>

# %%
c = 3.1415
print(type(c))
# Out:
# <type 'float'>

# %%
d = True
print(type(d))
# Out:
# <type 'bool'>

# %%
print('Rubens', type('Rubens'))
# Out:
# ('Rubens', <type 'str'>)

# %%
print(10, type(10))
# Out:
# (10, <type 'int'>)

# %%
print(3.14, type(3.14))
# Out:
# (3.14, <type 'float'>)

# %%
print(False, type(False))
# Out:
# (False, <type 'bool'>)

# %%
print(10 == 10)
# Out:
# True

# %%
print(10 == 10, type(10 == 10))
# Out:
# (True, <type 'bool'>)

# %%
print('L' == 'l', type('L' == 'l'))
# Out:
# (False, <type 'bool'>)

# %%
print('L' == 'L', type('L' == 'L'))
# Out:
# (True, <type 'bool'>)

# %%
print(0.0, type(0.0))
# Out:
# (0.0, <type 'float'>)

# %%
print(bool(''))  # vazio é falso
# Out:
# False

# %%
print(bool(0))  #valor zero é falso
# Out:
# False

# %%
print(bool(1))  #valor um é verdadeiro
# Out:
# True

# %%
# type casting
print(int(3.14), type(int(3.14)))  # fazendo um casting de float para int
# Out:
# (3, <type 'int'>)

# %%
print('rubens', type(bool('rubens')))  # fazendo um casting de str para bool
# Out:
# ('rubens', <type 'bool'>)

# %%
print('2019', type(float(2019))) # fazendo um casting de int para float
# Out:
# ('2019', <type 'float'>)

# %%
print('barbosa', (bool('barbosa')))  # um valor que não é vazio é verdadeiro
# Out:
# ('barbosa', True)

# %%
print('txt', int('txt'))  # não posso converter um texto pra inteiro
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-7391ea89c058> in <module>
# ----> 1 print('txt', int('txt'))  # não posso converter um texto pra inteiro
#
# ValueError: invalid literal for int() with base 10: 'txt'

# %%
print('10', type(int('10')))  # posso converter um número de str para inteiro por ex
# Out:
# ('10', <type 'int'>)
