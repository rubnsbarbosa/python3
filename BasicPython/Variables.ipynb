# %%
'''
Iniciar com letra, pode conter números, separar _, letras minúsculas
'''

name = 'Rubens'  # str
day = 10  # int
month = 'July'

print('Welcome ' + name + ', today ' + str(day) + ' of ' + str(month) + ' is a great day!')
# Out:
# Welcome Rubens, today 10 of July is a great day!

# %%
numero_pi = 3.1416  # float
print(numero_pi)
# Out:
# 3.1416

# %%
FLAG_A = True  # bool
print(FLAG_A)
# Out:
# True
