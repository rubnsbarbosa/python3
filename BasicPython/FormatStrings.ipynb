# %%
name = 'Rubens'
day = 10
month = 'July'
year = 2019

dolar = 4
print(f'o dolar ta {dolar:.2f}')

# %%
print(f'Welcome {name}, today is {day} of {month} {year}!')
print('Welcome {0} , today is {1} of {2} {3}'.format(name, day, month, year))
